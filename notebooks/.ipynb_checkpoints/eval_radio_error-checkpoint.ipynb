# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join('..')))
# sys.path.append(os.path.abspath(os.path.join('../utils')))
sys.path.append('../')

import cv2
import time
import json
from tqdm import tqdm
import numpy as np
import seaborn as sns
import pandas as pd
from utils.datagenerator import OpenEDS, EyeDataset
from metrics import *
from utils.utils import load_image
from imutils.paths import list_files
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from keras_fc_densenet import _create_fc_dense_net
from dense10_segmentator import DenseSegmentator
from tensorflow.keras import backend as K

from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
# dynamically grow GPU memory
config.gpu_options.allow_growth = True
set_session(tf.compat.v1.Session(config=config))

# %load_ext autoreload
# %autoreload 2
# Out:
# 2022-10-19 18:18:45.389644: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2022-10-19 18:18:45.394840: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2599990000 Hz
# 2022-10-19 18:18:45.395331: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562450a95660 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-10-19 18:18:45.395351: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-10-19 18:18:45.396775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-10-19 18:18:45.420806: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.421156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design computeCapability: 7.5
# coreClock: 1.335GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-10-19 18:18:45.421312: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 18:18:45.422518: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-10-19 18:18:45.423619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 18:18:45.423832: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 18:18:45.425322: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 18:18:45.425999: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-10-19 18:18:45.429183: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 18:18:45.429392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.429847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.430131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2022-10-19 18:18:45.430186: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 18:18:45.490178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 18:18:45.490197: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2022-10-19 18:18:45.490201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2022-10-19 18:18:45.490371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.490731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.491050: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.491343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5511 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-10-19 18:18:45.492704: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56244ff0aef0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-10-19 18:18:45.492715: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti with Max-Q Design, Compute Capability 7.5

# %%
def class_mean_iou(pred, label, class_info=None):
    pred = np.argmax(pred, axis=-1)
    label = np.argmax(label, axis=-1)
    unique_labels = np.unique(label)
    num_unique_labels = len(unique_labels)

    I = np.zeros(num_unique_labels)
    U = np.zeros(num_unique_labels)
    
    class_iou = []
    
    for index, val in enumerate(unique_labels):
        pred_i = pred == val
        label_i = label == val

        I[index] = float(np.sum(np.logical_and(label_i, pred_i)))
        U[index] = float(np.sum(np.logical_or(label_i, pred_i)))
        class_iou.append(np.mean(I[index] / U[index]))

    if not class_info:
        return np.mean(class_iou), np.std(class_iou)
    else:
        dict_class_iou = dict()
        # class_info: list of dicts
        # [{'source': 'eye', 'id': 0, 'name': 'bg'},
        # {'source': 'eye', 'id': 1, 'name': 'iris'},
        # {'source': 'eye', 'id': 1, 'name': 'pupil'}]
        _ids = [x['id'] for x in class_info]
        _classes = [x['name'] for x in class_info]
        
        if np.all(_ids == unique_labels):
            for lb_id, lb_class in zip(unique_labels, _classes):
                dict_class_iou[lb_class] = class_iou[lb_id]

        else:
            seen_classes = []
            for idx, lb_id in enumerate(unique_labels):
                lb_class = _classes[lb_id]
                seen_classes.append(lb_id)
                dict_class_iou[lb_class] = class_iou[idx]
            
            # not segmented classes cuz there is no class in image. 
            # Append 1.0
            for lb_id in _ids:
                if lb_id in seen_classes: continue
                lb_class = _classes[lb_id]
                dict_class_iou[lb_class] = 0.0
                class_iou.append(0.0)
        
        dict_class_iou['miou'] = np.mean(class_iou)
        dict_class_iou['stdiou'] = np.std(class_iou)
        
        return dict_class_iou

def class_mean_iou_old(pred, label):
    pred = np.argmax(pred, axis=-1)
    label = np.argmax(label, axis=-1)
    unique_labels = np.unique(label)
    num_unique_labels = len(unique_labels)

    I = np.zeros(num_unique_labels)
    U = np.zeros(num_unique_labels)
    class_iou = []
    
    for index, val in enumerate(unique_labels):
        pred_i = pred == val
        label_i = label == val

        I[index] = float(np.sum(np.logical_and(label_i, pred_i)))
        U[index] = float(np.sum(np.logical_or(label_i, pred_i)))
        class_iou.append(np.mean(I[index] / U[index]))

    dict_class_iou = {
        'bg': class_iou[0],
        'iris': class_iou[1],
        'pupil': class_iou[2],
        'sclera': class_iou[3],
        'miou': np.mean(class_iou),
        'stdiou:': np.std(class_iou)
    }
    
    return dict_class_iou

# %%
inifile_path = '../config/segmentator_dense10.ini'
# modelpath = '../models/epoch_124_miou_0.9345.h5'
modelpath = '/home/choppy/TOC/densenet10/models/weights/dense_models/blurry_gemini_dense_miou_0.9275.h5'

model = DenseSegmentator(modelpath=modelpath, inifile_path=inifile_path)
K.set_learning_phase(0)
# Out:
# 2022-10-19 18:18:45.874025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.874369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design computeCapability: 7.5
# coreClock: 1.335GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-10-19 18:18:45.874425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 18:18:45.874442: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-10-19 18:18:45.874458: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 18:18:45.874473: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 18:18:45.874489: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 18:18:45.874505: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-10-19 18:18:45.874520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 18:18:45.874580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.874899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.875167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2022-10-19 18:18:45.875401: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.875669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design computeCapability: 7.5
# coreClock: 1.335GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-10-19 18:18:45.875691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 18:18:45.875708: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-10-19 18:18:45.875723: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 18:18:45.875739: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 18:18:45.875755: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 18:18:45.875770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-10-19 18:18:45.875786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 18:18:45.875832: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.876134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.876387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2022-10-19 18:18:45.876404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 18:18:45.876408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2022-10-19 18:18:45.876412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2022-10-19 18:18:45.876478: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.876775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 18:18:45.877037: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5511 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)

# %%
ths = 0.7
dim = model.target_size[::-1]
# dataset_dir = "/home/choppy/TOC/datasets/openeds/ttv"
dataset_dir = "/home/choppy/TOC/datasets/alcohol/alcohol_v7.0"

Dataset = EyeDataset # select class to get intended dataset

testG = Dataset(batch_size=1, dim=dim)
testG.load_eyes(dataset_dir, "test")
testG.prepare()

valG = Dataset(batch_size=1, dim=dim)
valG.load_eyes(dataset_dir, "val")
valG.prepare()

# %%
im, lb = testG[0]
im.shape, lb.shape
# Out:
# ((1, 320, 320, 3), (1, 320, 320, 4))

# %% [markdown]
# # Model Info

# %%
# model.summary()

# %%
f'{model.count_params():,}'
# Out:
# '210,732'

# %% [markdown]
# # Pred one image

# %%
rows = 1
columns = 3

fig = plt.figure(figsize=(10, 8))
im, lb = testG[np.random.choice(len(testG))]
pred = model.predict(im[0])

fig.add_subplot(rows, columns, 1)
plt.title('image')
plt.axis('off')
plt.imshow(im[0])

fig.add_subplot(rows, columns, 2)
plt.title('label')
plt.axis('off')
plt.imshow(np.argmax(lb[0], axis=-1))

fig.add_subplot(rows, columns, 3)
plt.title('pred')
plt.axis('off')
plt.imshow(np.argmax(pred, axis=-1))

plt.show()
# Out:
# 2022-10-19 18:19:05.978126: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 18:19:06.656371: W tensorflow/stream_executor/gpu/asm_compiler.cc:81] Running ptxas --version returned 256
# 2022-10-19 18:19:06.696318: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-10-19 18:19:07.643957: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10

# %%
len(testG.image_info)
# Out:
# 2132

# %%
im, lb = testG[np.random.choice(len(testG))]
pred = model.predict(im[0])

pupil_id = next(a['id'] for a in testG.class_info if a['name'] == 'pupil')
p = np.argmax(pred, axis=-1)
pupil_pred = np.where(p == pupil_id, 1., 0.)
pupil_lb = lb[0, ..., 2]

euc_dist, r_diff = distance_error(pupil_lb, pupil_pred)
euc_dist, r_diff
# Out:
# (0.0, 1)

# %%
def get_distance_error(output_image, lb):
    # lb_argmax = np.argmax(output_image, axis=-1)
    pupil_lb = lb[0, ..., pupil_id]
    # pupil_pred = np.where(lb_argmax == pupil_id, 1., 0.)
    pupil_pred = np.where(output_image[..., pupil_id] > ths, 1., 0.)
    derror = distance_error(pupil_lb, pupil_pred)
    return derror

# %% [markdown]
# # Evaluate final IoU of val set

# %%
val_iou = []
pupil_id = next(a['id'] for a in valG.class_info if a['name'] == 'pupil')

for i in tqdm(range(len(valG)), desc='val set'):
    fname = valG.image_info[i]['path']
    im, lb = valG[i]
    image = model.load_image(fname)
    start = time.time()
    info = model.forward(image) # this line get all info, radii and estimations
    end = time.time()
    output_image = model.predict(im[0]) # this is for the class_mean_iou function

    iou = class_mean_iou(output_image, lb[0, ...], valG.class_info)
    val_iou.append({
        'fname': fname,
        'miou': iou['miou'],
        'inf_time': end-start,
        '_classes': { c['name']: iou[c['name']] for c in valG.class_info },
    })
    # break

miou = np.mean([elem['miou'] for elem in val_iou])
std_iou = np.std([elem['miou'] for elem in val_iou])

_cls_iou = {
	c['name']: [ elem['_classes'][c['name']] for elem in val_iou ] for c in valG.class_info
}

print(f'mean iou: {miou}')
print(f'std iou: {std_iou}\n')

for c in _cls_iou:
	print(f'miou {c}: {np.mean(_cls_iou[c])}')
	print(f'std {c}: {np.std(_cls_iou[c])}\n')
# Out:
# val set:   0%|                                                                                                                                                                            | 0/4261 [00:00<?, ?it/s]/home/choppy/TOC/densenet10/dense10_segmentator.py:156: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   a, _, _, _ = np.linalg.lstsq(A, B)
# val set:  17%|███████████████████████████▎                                                                                                                                      | 719/4261 [01:40<09:48,  6.02it/s]An error ocurred getting minmax(y) inside LMS3
# val set:  23%|████████████████████████████████████▍                                                                                                                             | 959/4261 [02:16<08:41,  6.33it/s]An error ocurred getting minmax(y) inside LMS3
# val set:  35%|████████████████████████████████████████████████████████▊                                                                                                        | 1502/4261 [03:38<07:13,  6.36it/s]
# {'id': '0010622_LG_E_3_0_0_R_M_N_N_1987_8_2017.bmp', 'source': 'eye', 'path': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0010622_LG_E_3_0_0_R_M_N_N_1987_8_2017.bmp', 'width': 640, 'height': 480, 'polygons': [{'name': 'polygon', 'all_points_x': [350, 352, 357, 385, 419, 447, 478, 509, 540, 567, 577, 584, 588, 588, 586, 579, 571, 564, 559, 538, 522, 521, 518, 514, 511, 515, 512, 510, 501, 502, 483, 458, 433, 418, 407, 384, 364, 352, 350], 'all_points_y': [206, 194, 179, 167, 154, 148, 146, 146, 150, 156, 162, 178, 195, 210, 231, 250, 267, 281, 287, 294, 300, 296, 295, 296, 297, 302, 304, 300, 300, 305, 309, 312, 315, 315, 312, 290, 263, 236, 218]}, {'name': 'ellipse', 'cx': 476, 'cy': 210, 'rx': 36, 'ry': 36}, {'name': 'polygon', 'all_points_x': [416, 392, 353, 316, 276, 246, 244, 244, 271, 313, 357, 352, 350, 350, 352, 364, 385, 406], 'all_points_y': [315, 315, 313, 307, 298, 285, 280, 274, 246, 209, 179, 195, 207, 219, 236, 263, 291, 311]}, {'name': 'polygon', 'all_points_x': [559, 593, 640, 639, 608, 577, 584, 588, 588, 586, 579, 569, 563], 'all_points_y': [287, 272, 256, 188, 175, 162, 178, 195, 212, 231, 252, 270, 282]}], 'num_ids': [1, 2, 3, 3]} 3 {'name': 'polygon', 'all_points_x': [559, 593, 640, 639, 608, 577, 584, 588, 588, 586, 579, 569, 563], 'all_points_y': [287, 272, 256, 188, 175, 162, 178, 195, 212, 231, 252, 270, 282]} index 640 is out of bounds for axis 1 with size 640
# val set:  38%|█████████████████████████████████████████████████████████████▋                                                                                                   | 1632/4261 [03:58<06:17,  6.96it/s]/home/choppy/TOC/densenet10/utils/datagenerator.py:321: FutureWarning: `draw.circle` is deprecated in favor of `draw.disk`.`draw.circle` will be removed in version 0.19
#   rr, cc = skimage.draw.circle(p["cy"], p["cx"], p["r"])
# val set:  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                 | 3810/4261 [09:46<01:13,  6.14it/s]An error ocurred getting minmax(y) inside LMS3
# val set: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4261/4261 [10:58<00:00,  6.47it/s]
# mean iou: 0.9147812511496727
# std iou: 0.03682619475039492
#
# miou eye: 0.9874233340577375
# std eye: 0.006067204448669832
#
# miou iris: 0.9249598030737601
# std iris: 0.03631771477280639
#
# miou pupil: 0.9166634531780258
# std pupil: 0.06871340700369576
#
# miou sclera: 0.8300784142891675
# std sclera: 0.06564581765454708

# %%
d2 = Dataset(batch_size=1, dim=dim)
d2.load_eyes(dataset_dir, "test")
d2.prepare()

d3 = Dataset(batch_size=1, dim=dim)
d3.load_eyes(dataset_dir, "val")
d3.prepare()

generators = [
	(d2, 'test'), 
	(d3, 'val'),
]

all_iou = [
    # { 
    # fname: str
    # miou: float,
    # coords_pupil: tuple(x, y, r)
    # inf_time: float
    # _classes: dict with:
        # bg: float
        # sclera: float
        # iris: float
        # pupil: float
    # }
]

# %%
image = model.load_image(fname)
info = model.forward(image)

# %%
plt.imshow(np.argmax(info['mask'], axis=-1))

# %%
r_pupil = model.get_radio(mask=output_image, rtype=model.rtype) # may raise error if no pupil was detected

# %%
info['mask'].shape
# Out:
# (480, 640, 4)

# %%
files_with_error = []
pupil_id = next(a['id'] for a in testG.class_info if a['name'] == 'pupil')

for gen, _set in generators:
	for i in tqdm(range(len(gen)), leave=False, desc=f'{_set} set'):
		fname = gen.image_info[i]['path']
		im, lb = gen[i]
		image = model.load_image(fname)
		start = time.time()
		info = model.forward(image) # this line get all info, radii and estimations
		end = time.time()
		output_image = model.predict(im[0]) # this is for the class_mean_iou function
		
		try:
			r_pupil = (info['pupil_x'], info['pupil_y'], info['pupil_r_min'], info['pupil_r_max'])
			pupil_err = get_distance_error(output_image, lb)
		except ValueError:
			print(f'pupil not detected for image ({i}) {gen.image_info[i]["path"]}')
			files_with_error.append(fname)
			continue # no append info for this image
            
		iou = class_mean_iou(output_image, lb[0, ...], gen.class_info)
		all_iou.append({
			'fname': fname,
			'set': _set,
			'miou': iou['miou'],
			'coords_pupil': r_pupil,
			'pupil_err': pupil_err,
			'inf_time': end-start,
			'_classes': { c['name']: iou[c['name']] for c in gen.class_info },
		})

		# break
# Out:
# test set:  32%|████████████████████████████████████████████████████▎                                                                                                            | 692/2132 [01:57<04:45,  5.05it/s]An error ocurred getting minmax(y) inside LMS3
# test set:  33%|████████████████████████████████████████████████████▍                                                                                                            | 694/2132 [01:57<04:14,  5.65it/s]
# pupil not detected for image (692) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0009017_Iritech_E_2_3_0_R_M_N_N_1982_35_2017.bmp
# test set:  68%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                   | 1454/2132 [04:23<02:22,  4.76it/s]
# {'id': '0004544_Iritech_E_1_2_3_R_F_Y_N_1992_6_2017.bmp', 'source': 'eye', 'path': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0004544_Iritech_E_1_2_3_R_F_Y_N_1992_6_2017.bmp', 'width': 640, 'height': 480, 'polygons': [{'name': 'polygon', 'all_points_x': [329, 315, 305, 296, 292, 291, 293, 299, 311, 325, 343, 367, 391, 417, 451, 477, 505, 524, 536, 541, 542, 534, 523, 511, 494, 463, 433, 409, 385, 360], 'all_points_y': [182, 197, 214, 237, 259, 278, 297, 315, 335, 352, 367, 379, 387, 390, 387, 378, 357, 335, 309, 286, 256, 223, 201, 187, 174, 167, 165, 165, 167, 172]}, {'name': 'ellipse', 'cx': 421, 'cy': 269, 'rx': 56, 'ry': 56}, {'name': 'polygon', 'all_points_x': [418, 418, 447, 485, 518, 559, 606, 623, 631, 640, 626, 609, 579, 553, 525, 493, 511, 523, 534, 542, 541, 535, 523, 505, 479, 451], 'all_points_y': [390, 398, 399, 398, 395, 387, 377, 349, 323, 291, 261, 237, 211, 194, 182, 173, 187, 201, 223, 255, 287, 311, 336, 358, 377, 387]}, {'name': 'polygon', 'all_points_x': [417, 383, 347, 312, 282, 253, 229, 217, 217, 227, 243, 269, 296, 313, 330, 315, 305, 295, 291, 291, 294, 299, 311, 326, 343, 365, 391, 417], 'all_points_y': [398, 393, 385, 371, 351, 330, 307, 287, 274, 253, 233, 210, 193, 187, 181, 198, 215, 238, 263, 279, 298, 317, 335, 353, 367, 378, 387, 390]}], 'num_ids': [1, 2, 3, 3]} 3 {'name': 'polygon', 'all_points_x': [418, 418, 447, 485, 518, 559, 606, 623, 631, 640, 626, 609, 579, 553, 525, 493, 511, 523, 534, 542, 541, 535, 523, 505, 479, 451], 'all_points_y': [390, 398, 399, 398, 395, 387, 377, 349, 323, 291, 261, 237, 211, 194, 182, 173, 187, 201, 223, 255, 287, 311, 336, 358, 377, 387]} index 640 is out of bounds for axis 1 with size 640
# val set:  17%|███████████████████████████▎                                                                                                                                      | 719/4261 [03:54<20:58,  2.81it/s]An error ocurred getting minmax(y) inside LMS3
# val set:  17%|███████████████████████████▎                                                                                                                                      | 720/4261 [03:54<20:22,  2.90it/s]
# pupil not detected for image (719) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0010566_Iritech_E_3_0_4_R_M_N_N_1987_44_2017.bmp
# val set:  23%|████████████████████████████████████▍                                                                                                                             | 959/4261 [05:21<21:05,  2.61it/s]An error ocurred getting minmax(y) inside LMS3
# val set:  23%|████████████████████████████████████▍                                                                                                                             | 960/4261 [05:21<20:26,  2.69it/s]
# pupil not detected for image (959) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0002371_Iritech_E_0_2_4_L_M_N_N_1976_53_2017.bmp
# val set:  35%|████████████████████████████████████████████████████████▊                                                                                                        | 1502/4261 [07:49<08:33,  5.38it/s]
# {'id': '0010622_LG_E_3_0_0_R_M_N_N_1987_8_2017.bmp', 'source': 'eye', 'path': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0010622_LG_E_3_0_0_R_M_N_N_1987_8_2017.bmp', 'width': 640, 'height': 480, 'polygons': [{'name': 'polygon', 'all_points_x': [350, 352, 357, 385, 419, 447, 478, 509, 540, 567, 577, 584, 588, 588, 586, 579, 571, 564, 559, 538, 522, 521, 518, 514, 511, 515, 512, 510, 501, 502, 483, 458, 433, 418, 407, 384, 364, 352, 350], 'all_points_y': [206, 194, 179, 167, 154, 148, 146, 146, 150, 156, 162, 178, 195, 210, 231, 250, 267, 281, 287, 294, 300, 296, 295, 296, 297, 302, 304, 300, 300, 305, 309, 312, 315, 315, 312, 290, 263, 236, 218]}, {'name': 'ellipse', 'cx': 476, 'cy': 210, 'rx': 36, 'ry': 36}, {'name': 'polygon', 'all_points_x': [416, 392, 353, 316, 276, 246, 244, 244, 271, 313, 357, 352, 350, 350, 352, 364, 385, 406], 'all_points_y': [315, 315, 313, 307, 298, 285, 280, 274, 246, 209, 179, 195, 207, 219, 236, 263, 291, 311]}, {'name': 'polygon', 'all_points_x': [559, 593, 640, 639, 608, 577, 584, 588, 588, 586, 579, 569, 563], 'all_points_y': [287, 272, 256, 188, 175, 162, 178, 195, 212, 231, 252, 270, 282]}], 'num_ids': [1, 2, 3, 3]} 3 {'name': 'polygon', 'all_points_x': [559, 593, 640, 639, 608, 577, 584, 588, 588, 586, 579, 569, 563], 'all_points_y': [287, 272, 256, 188, 175, 162, 178, 195, 212, 231, 252, 270, 282]} index 640 is out of bounds for axis 1 with size 640
# val set:  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                 | 3810/4261 [13:52<01:15,  5.94it/s]An error ocurred getting minmax(y) inside LMS3
# val set:  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                 | 3812/4261 [13:53<01:13,  6.10it/s]
# pupil not detected for image (3810) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0000587_IriTech_E_0_0_3_R_M_N_N_1981_68_2017.bmp

# %% [markdown]
# # Evaluation Metrics

# %%
len(files_with_error)
# Out:
# 4

# %%
print(f'Total images: {len(all_iou)}\n')
print(f'Mean Dist error: {np.mean([m["pupil_err"][0] for m in all_iou])}')
print(f'Std Dist error: {np.std([m["pupil_err"][0] for m in all_iou])}')
print(f'Max Dist error: {np.max([m["pupil_err"][0] for m in all_iou])}')
print(f'Min Dist error: {np.min([m["pupil_err"][0] for m in all_iou])}')
print('\n', '-'*40, '\n')
print(f'Mean Radio error: {np.mean([m["pupil_err"][-1] for m in all_iou])}')
print(f'Std Radio error: {np.std([m["pupil_err"][-1] for m in all_iou])}')
print(f'Max Radio error: {np.max([m["pupil_err"][-1] for m in all_iou])}')
print(f'Min Radio error: {np.min([m["pupil_err"][-1] for m in all_iou])}')
print('\n', '-'*40, '\n')
print(f'Mean IoU: {np.mean([m["miou"] for m in all_iou])}')
print(f'Std IoU: {np.std([m["miou"] for m in all_iou])}')
print(f'Min IoU: {np.min([m["miou"] for m in all_iou])}')
print(f'Max IoU: {np.max([m["miou"] for m in all_iou])}')
print(f'Avg time: {np.mean([m["inf_time"] for m in all_iou])}')
print(f'Std time: {np.std([m["inf_time"] for m in all_iou])}')
print('\n', '-'*40, '\n')

for key in all_iou[0]['_classes'].keys():
    print(f'{key} miou: {np.mean([m["_classes"][key] for m in all_iou])}')
# Out:
# Total images: 6389
#
# Mean Dist error: 0.8557409051958641
# Std Dist error: 0.9829014992860879
# Max Dist error: 19.4164878389476
# Min Dist error: 0.0
#
#  ----------------------------------------
#
# Mean Radio error: 1.0264517138832367
# Std Radio error: 1.178837874935187
# Max Radio error: 24
# Min Radio error: 0
#
#  ----------------------------------------
#
# Mean IoU: 0.9150630507015434
# Std IoU: 0.03469061481916676
# Min IoU: 0.5426401683979685
# Max IoU: 0.9700468422258115
# Avg time: 0.08766896595210794
# Std time: 0.038089626138408036
#
#  ----------------------------------------
#
# eye miou: 0.9874097346809839
# iris miou: 0.9252129729508684
# pupil miou: 0.9173107002211249
# sclera miou: 0.8303187949531962

# %% [markdown]
# # Check Radio Errors

# %% [markdown]
# ### max radio diff

# %%
id_m = np.argmax([m["pupil_err"][-1] for m in all_iou])
all_iou[id_m]
# Out:
# {'fname': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0014010_gemini_1_15499172424147453_164709_57.png',
#  'set': 'val',
#  'miou': 0.5887725665564512,
#  'coords_pupil': (208, 267, 49, 42),
#  'pupil_err': (19.4164878389476, 24),
#  'inf_time': 0.06326603889465332,
#  '_classes': {'eye': 0.9593802581504861,
#   'iris': 0.5960106382978724,
#   'pupil': 0.1466992665036675,
#   'sclera': 0.6530001032737788}}

# %% [markdown]
# ### max distance error

# %%
id_m = np.argmax([m["pupil_err"][0] for m in all_iou])
all_iou[id_m]
# Out:
# {'fname': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0014010_gemini_1_15499172424147453_164709_57.png',
#  'set': 'val',
#  'miou': 0.5887725665564512,
#  'coords_pupil': (208, 267, 49, 42),
#  'pupil_err': (19.4164878389476, 24),
#  'inf_time': 0.06326603889465332,
#  '_classes': {'eye': 0.9593802581504861,
#   'iris': 0.5960106382978724,
#   'pupil': 0.1466992665036675,
#   'sclera': 0.6530001032737788}}

# %% [markdown]
# # Worst Image

# %%
d_names = [elem['fname'] for elem in all_iou]
d_set = [elem['set'] for elem in all_iou]
s_iou = [elem['miou'] for elem in all_iou]

# %%
min_iou = np.where(np.array(s_iou) == np.min(s_iou))[0][0]
fname_min_iou = d_names[min_iou]
set_min_iou = d_set[min_iou]
set_min_iou, fname_min_iou, min_iou
# Out:
# ('test',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0010492_Iritech_E_3_0_4_L_M_N_N_1987_46_2017.bmp',
#  1816)

# %%
_miou = s_iou.copy()
_miou = np.sort(_miou)
_miou[:10]
# Out:
# array([0.54264017, 0.56968508, 0.58877257, 0.60577591, 0.61277983,
#        0.64341085, 0.65087753, 0.66280374, 0.66412053, 0.68069033])

# %%
d = [gen[0] for gen in generators if gen[1] == set_min_iou][0]
fname = fname_min_iou.split('/')[-1]
im, lb = d.get_image_by_name(fname)

output_image = model.predict(im[0])
iou = class_mean_iou(output_image, lb[0, ...], d.class_info)
output_image = np.argmax(output_image, axis=-1)

plt.imshow(output_image)
plt.axis('off')
iou
# Out:
# {'eye': 0.9788786873231408,
#  'iris': 0.697841726618705,
#  'pupil': 0.08611825192802057,
#  'sclera': 0.40772200772200773,
#  'miou': 0.5426401683979685,
#  'stdiou': 0.3320416914205771}

# %%
plt.imshow(im[0, ...])
plt.axis('off')
# Out:
# (-0.5, 319.5, 319.5, -0.5)

# %%
plt.imshow(np.argmax(lb[0, ...], axis=-1))
plt.axis('off')
# Out:
# (-0.5, 319.5, 319.5, -0.5)

# %%
files_with_error
# Out:
# ['/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0009017_Iritech_E_2_3_0_R_M_N_N_1982_35_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0010566_Iritech_E_3_0_4_R_M_N_N_1987_44_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0002371_Iritech_E_0_2_4_L_M_N_N_1976_53_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0000587_IriTech_E_0_0_3_R_M_N_N_1981_68_2017.bmp']

# %% [markdown]
# # Images with errors

# %%
fig = plt.figure(figsize=(12, 12))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    try:
        impath = files_with_error[i-1]
    except IndexError as ie:
        # print('no error files')
        break
        
    if 'train' in impath: d = d1
    elif 'test' in impath: d = d2
    else: d = d3
    imname = os.path.basename(impath)
    im, lb = d.get_image_by_name(imname)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(im[0])
plt.show()

# %% [markdown]
# # Ground Truth

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(1, columns*rows +1):
    try:
        impath = files_with_error[i-1]
    except IndexError as ie:
        print('no error files')
        break
    if 'train' in impath: d = d1
    elif 'test' in impath: d = d2
    else: d = d3
    imname = os.path.basename(impath)
    im, lb = d.get_image_by_name(imname)
    lb = np.argmax(lb[0], axis=-1)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(lb)
plt.show()
# Out:
# no error files

# %% [markdown]
# # Prediction

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(1, columns*rows +1):
    try:
        impath = files_with_error[i-1]
    except IndexError as ie:
        print('no error files')
        break
    if 'train' in impath: d = d1
    elif 'test' in impath: d = d2
    else: d = d3
    imname = os.path.basename(impath)
    im, lb = d.get_image_by_name(imname)
    pred = model.predict(im[0])
    pred = np.argmax(pred, axis=-1)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(pred)
plt.show()
# Out:
# no error files

# %%
fig = plt.figure(figsize=(7, 4))
plt.title('Center dist error')
dst_err = [elem['pupil_err'][0] for elem in all_iou]
sns.distplot(dst_err, bins=int(max(dst_err)))
# sns.distplot(dst_err, bins=10)
plt.xlabel('Euclidean dist (px)')
print('bines:', int(max(dst_err)))
# sns.distplot(dst_err)
# Out:
# /home/choppy/TOC/.conda/envs/tf22/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# bines: 19

# %%
fig, ax = plt.subplots()
data = [elem['pupil_err'][0] for elem in all_iou]
data = np.sort(np.array(data))

if data[-1] > 18:
	data = data[:-3]
	
plt.title(f'Center Dist Error - Total images: {len(data)}')
counts, bins, patches = ax.hist(data, facecolor='blue', edgecolor='gray')

# Set the ticks to be at the edges of the bins.
ax.set_xticks(bins)
ax.set_ylim(0, len(data))
# Set the xaxis's tick labels to be formatted with 1 decimal place...
# ax.xaxis.set_major_formatter(FormatStrFormatter('%0.1f'))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))

# Change the colors of bars at the edges...
# twentyfifth, seventyfifth = np.percentile(data, [5, 95])
# for patch, rightside, leftside in zip(patches, bins[1:], bins[:-1]):
#     if rightside < twentyfifth:
#         patch.set_facecolor('red')
#     elif leftside > seventyfifth:
#         patch.set_facecolor('green')

# Label the raw counts and the percentages below the x-axis...
bin_centers = 1e-4 * np.diff(bins) + bins[:-1]
for count, x in zip(counts, bin_centers):
    # Label the raw counts
    ax.annotate(str(int(count)), xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -20), textcoords='offset points', va='top', ha='center')

    # Label the percentages
    percent = '%0.0f%%' % (100 * float(count) / counts.sum())
    ax.annotate(percent, xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -34), textcoords='offset points', va='top', ha='center')

# %%
fig = plt.figure(figsize=(7, 4))
plt.title('Radio error dist')
rad_err = [elem['pupil_err'][-1] for elem in all_iou]
sns.distplot(rad_err, bins=int(max(rad_err)))
# sns.distplot(dst_err, bins=10)
plt.xlabel('Radii (px)')
print('bines:', int(max(rad_err)))
# Out:
# bines: 24
# /home/choppy/TOC/.conda/envs/tf22/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots()
data = [elem['pupil_err'][-1] for elem in all_iou]
data = np.sort(np.array(data))

if data[-1] > 20:
	data = data[:-3]

plt.title(f'Pupil Error Dist - Total images: {len(data)}')
counts, bins, patches = ax.hist(data, facecolor='green', edgecolor='gray')

# Set the ticks to be at the edges of the bins.
ax.set_xticks(bins)
ax.set_ylim(0, len(data))
# Set the xaxis's tick labels to be formatted with 1 decimal place...
# ax.xaxis.set_major_formatter(FormatStrFormatter('%0.1f'))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))

# Change the colors of bars at the edges...
# twentyfifth, seventyfifth = np.percentile(data, [25, 75])
# for patch, rightside, leftside in zip(patches, bins[1:], bins[:-1]):
#     if rightside < twentyfifth:
#         patch.set_facecolor('red')
#     elif leftside > seventyfifth:
#         patch.set_facecolor('green')

# Label the raw counts and the percentages below the x-axis...
bin_centers = 1e-4 * np.diff(bins) + bins[:-1]
for count, x in zip(counts, bin_centers):
    # Label the raw counts
    ax.annotate(str(int(count)), xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -20), textcoords='offset points', va='top', ha='center')

    # Label the percentages
    percent = '%0.0f%%' % (100 * float(count) / counts.sum())
    ax.annotate(percent, xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -34), textcoords='offset points', va='top', ha='center')
