# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))
# sys.path.append(os.path.abspath(os.path.join('../utils')))
sys.path.append('../')

import cv2
import time
import json
from tqdm import tqdm
import numpy as np
import seaborn as sns
import pandas as pd
from utils.datagenerator import EyeDataset, NoScleraDataset
from metrics import *
from utils.utils import load_image
from imutils.paths import list_files
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from keras_fc_densenet import _create_fc_dense_net
from tensorflow.keras import backend as K

from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
# dynamically grow GPU memory
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))
# Out:
# /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def class_mean_iou(pred, label, class_info=None):
    pred = np.argmax(pred, axis=-1)
    label = np.argmax(label, axis=-1)
    unique_labels = np.unique(label)
    num_unique_labels = len(unique_labels)

    I = np.zeros(num_unique_labels)
    U = np.zeros(num_unique_labels)
    
    class_iou = []
    
    for index, val in enumerate(unique_labels):
        pred_i = pred == val
        label_i = label == val

        I[index] = float(np.sum(np.logical_and(label_i, pred_i)))
        U[index] = float(np.sum(np.logical_or(label_i, pred_i)))
        class_iou.append(np.mean(I[index] / U[index]))

    if not class_info:
        return np.mean(class_iou), np.std(class_iou)
    else:
        dict_class_iou = dict()
        # class_info: list of dicts
        # [{'source': 'eye', 'id': 0, 'name': 'bg'},
        # {'source': 'eye', 'id': 1, 'name': 'iris'},
        # {'source': 'eye', 'id': 1, 'name': 'pupil'}]
        _ids = [x['id'] for x in class_info]
        _classes = [x['name'] for x in class_info]
        
        if np.all(_ids == unique_labels):
            for lb_id, lb_class in zip(unique_labels, _classes):
                dict_class_iou[lb_class] = class_iou[lb_id]

        else:
            seen_classes = []
            for idx, lb_id in enumerate(unique_labels):
                lb_class = _classes[lb_id]
                seen_classes.append(lb_id)
                dict_class_iou[lb_class] = class_iou[idx]
            
            # not segmented classes cuz there is no class in image. 
            # Append 1.0
            for lb_id in _ids:
                if lb_id in seen_classes: continue
                lb_class = _classes[lb_id]
                dict_class_iou[lb_class] = 0.0
                class_iou.append(0.0)
        
        dict_class_iou['miou'] = np.mean(class_iou)
        dict_class_iou['stdiou'] = np.std(class_iou)
        
        return dict_class_iou

def class_mean_iou_old(pred, label):
    pred = np.argmax(pred, axis=-1)
    label = np.argmax(label, axis=-1)
    unique_labels = np.unique(label)
    num_unique_labels = len(unique_labels)

    I = np.zeros(num_unique_labels)
    U = np.zeros(num_unique_labels)
    class_iou = []
    
    for index, val in enumerate(unique_labels):
        pred_i = pred == val
        label_i = label == val

        I[index] = float(np.sum(np.logical_and(label_i, pred_i)))
        U[index] = float(np.sum(np.logical_or(label_i, pred_i)))
        class_iou.append(np.mean(I[index] / U[index]))

    dict_class_iou = {
        'bg': class_iou[0],
        'iris': class_iou[1],
        'pupil': class_iou[2],
        'sclera': class_iou[3],
        'miou': np.mean(class_iou),
        'stdiou:': np.std(class_iou)
    }
    
    return dict_class_iou

# %% [markdown]
# # Older Models Load

# %%
# inputs = Input(shape=testG.input_shape)

# logits = _create_fc_dense_net(
#     nb_classes=4, final_softmax=True, img_input=inputs, 
#     nb_dense_block=4, growth_rate=6, nb_layers_per_block=3,
#     dropout_rate=0.0
# )

# model = Model(inputs=inputs, outputs=logits)
# # model.load_weights('../models/090620_models_1eye/epoch_086_miou_0.9497.h5')
# # model.load_weights('../models/oneye/01_15062020/epoch_092_miou_0.9455.h5')
# # model.load_weights('../models/iris_4classes/02_18062020/epoch_079_miou_0.9480.h5')
# model.load_weights('../dense_segmenter/weights/dense_models/10_dense_miou_0.9480.h5')
# # model.load_weights('../dense_segmenter/weights/dense_models/blurry_gemini_dense_miou_0.9275.h5')

# %%
# config_dir = '../models/tiny_models/08022021_maxpool_relu'
# config_dir = '../models/gemini_alcohol_antifaz/16122020_db_6.0'
config_dir = '../models/tiny_models/alcohol_models'

config_json = list(sorted(list_files(config_dir, contains='.json')))[0]
config_json
# Out:
# '../models/tiny_models/alcohol_models/config.json'

# %%
with open(config_json) as js:
	# create model with config file
	config_data = json.load(js)
	dim = tuple(config_data['img_input'][:-1])
	config_data['img_input'] = Input(shape=config_data['img_input'])
	logits = _create_fc_dense_net(**config_data)
	model = Model(inputs=config_data['img_input'], outputs=logits)
	
	# load best weights
	weights = sorted(list(list_files(config_dir, contains='.h5')))
	model.load_weights(weights[-1])

K.set_learning_phase(0)
# Out:
# WARNING:tensorflow:From /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/choppy/anaconda3/envs/alcohol/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
ths = 0.7
# dim = (480, 640) # cambiar input por el cual fue entrenado el modelo
dataset_dir = '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0'

Dataset = NoScleraDataset

testG = Dataset(batch_size=1, dim=dim)
testG.load_eyes(dataset_dir, "test")
testG.prepare()

valG = Dataset(batch_size=1, dim=dim)
valG.load_eyes(dataset_dir, "val")
valG.prepare()

# %%
im, lb = testG[0]
im.shape, lb.shape
# Out:
# ((1, 240, 320, 3), (1, 240, 320, 3))

# %% [markdown]
# # Model Info

# %%
# model.summary()

# %%
f'{model.count_params():,}'
# Out:
# '57,146'

# %% [markdown]
# # Pred one image

# %%
rows = 1
columns = 3

fig = plt.figure(figsize=(10, 8))
im, lb = valG[np.random.choice(len(valG))]
pred = model.predict(im)[0]

fig.add_subplot(rows, columns, 1)
plt.title('image')
plt.axis('off')
plt.imshow(im[0])

fig.add_subplot(rows, columns, 2)
plt.title('label')
plt.axis('off')
plt.imshow(np.argmax(lb[0], axis=-1))

fig.add_subplot(rows, columns, 3)
plt.title('pred')
plt.axis('off')
plt.imshow(np.argmax(pred, axis=-1))

plt.show()

# %%
len(testG.image_info)
# Out:
# 2132

# %%
im, lb = testG[np.random.choice(len(testG))]
# im, lb = valG.get_image_by_name('0001753_IriTech_E_1_4_1_R_M_N_N_1979_0_2017.bmp')
pred = model.predict(im)[0]

pupil_id = next(a['id'] for a in testG.class_info if a['name'] == 'pupil')
p = np.argmax(pred, axis=-1)
pupil_pred = np.where(p == pupil_id, 1., 0.)
pupil_lb = lb[0, ..., 2]

euc_dist, r_diff = distance_error(pupil_lb, pupil_pred)
euc_dist, r_diff
# Out:
# (2.0, 0)

# %%
def get_distance_error(output_image, lb):
    # lb_argmax = np.argmax(output_image, axis=-1)
    pupil_lb = lb[0, ..., pupil_id]
    # pupil_pred = np.where(lb_argmax == pupil_id, 1., 0.)
    pupil_pred = np.where(output_image[..., pupil_id] > ths, 1., 0.)
    derror = distance_error(pupil_lb, pupil_pred)
    return derror

# %% [markdown]
# # Evaluate final IoU of val set

# %%
val_iou = []
pupil_id = next(a['id'] for a in valG.class_info if a['name'] == 'pupil')

for i in tqdm(range(len(valG)), desc='val set'):
    fname = valG.image_info[i]['path']
    im, lb = valG[i]
    start = time.time()
    output_image = model.predict(im)[0]
    end = time.time()

    iou = class_mean_iou(output_image, lb[0, ...], valG.class_info)
    val_iou.append({
        'fname': fname,
        'miou': iou['miou'],
        'inf_time': end-start,
        '_classes': { c['name']: iou[c['name']] for c in valG.class_info },
    })

miou = np.mean([elem['miou'] for elem in val_iou])
std_iou = np.std([elem['miou'] for elem in val_iou])

_cls_iou = {
	c['name']: [ elem['_classes'][c['name']] for elem in val_iou ] for c in valG.class_info
}

print(f'mean iou: {miou}')
print(f'std iou: {std_iou}\n')

for c in _cls_iou:
	print(f'miou {c}: {np.mean(_cls_iou[c])}')
	print(f'std {c}: {np.std(_cls_iou[c])}\n')
# Out:
# val set: 100%|██████████| 4261/4261 [03:20<00:00, 21.21it/s]
# mean iou: 0.9148364177875493
# std iou: 0.04354976715133515
#
# miou eye: 0.9884784985392814
# std eye: 0.010157736301071129
#
# miou iris: 0.8628697169066827
# std iris: 0.06478436324653535
#
# miou pupil: 0.8931610379166841
# std pupil: 0.08585527497262832

# %%
d1 = Dataset(batch_size=1, dim=dim)
d1.load_eyes(dataset_dir, "train")
d1.prepare()

d2 = Dataset(batch_size=1, dim=dim)
d2.load_eyes(dataset_dir, "test")
d2.prepare()

d3 = Dataset(batch_size=1, dim=dim)
d3.load_eyes(dataset_dir, "val")
d3.prepare()

generators = [
	(d1, 'train'), 
	(d2, 'test'), 
	(d3, 'val'),
]

all_iou = [
    # { 
    # fname: str
    # miou: float,
    # coords_pupil: tuple(x, y, r)
    # inf_time: float
    # _classes: dict with:
        # bg: float
        # sclera: float
        # iris: float
        # pupil: float
    # }
]

# %%
files_with_error = []
pupil_id = next(a['id'] for a in testG.class_info if a['name'] == 'pupil')

for gen, _set in generators:
	for i in tqdm(range(len(gen)), leave=False, desc=f'{_set} set'):
		fname = gen.image_info[i]['path']
		# if 'gemini' in [a.lower() for a in fname.split('_')]: continue
		im, lb = gen[i]
		start = time.time()
		output_image = model.predict(im)[0]
		end = time.time()
		# for_pupil = np.argmax(output_image, axis=-1)
		# pupil = np.where(for_pupil == pupil_id, True, False)
		pupil = np.where(output_image[..., pupil_id] > ths, True, False)
		try:
			r_pupil = get_radio(pupil) # may raise error if no pupil was detected
			pupil_err = get_distance_error(output_image, lb)
		except ValueError:
			print(f'pupil not detected for image ({i}) {gen.image_info[i]["path"]}')
			files_with_error.append(fname)
			continue # no append info for this image
		iou = class_mean_iou(output_image, lb[0, ...], gen.class_info)
		all_iou.append({
			'fname': fname,
			'set': _set,
			'miou': iou['miou'],
			'coords_pupil': r_pupil,
			'pupil_err': pupil_err,
			'inf_time': end-start,
			'_classes': { c['name']: iou[c['name']] for c in gen.class_info },
		})
# Out:
# train set:   3%|▎         | 412/14916 [00:21<11:27, 21.11it/s]
# pupil not detected for image (409) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0013441_gemini_1_15499172424147453_164448_1.png
# train set:   5%|▍         | 741/14916 [00:37<12:34, 18.79it/s]
# pupil not detected for image (738) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0015765_gemini_0_15499172424147453_003222_59.png
# train set:   7%|▋         | 1041/14916 [00:53<12:05, 19.13it/s]
# pupil not detected for image (1037) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016635_gemini_1_15499172424147453_001259_20.png
# train set:   8%|▊         | 1132/14916 [00:57<10:59, 20.91it/s]
# pupil not detected for image (1127) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000516_IriTech_E_0_0_3_L_M_N_N_1981_69_2017.bmp
# train set:  14%|█▍        | 2120/14916 [01:48<12:01, 17.74it/s]
# pupil not detected for image (2116) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016671_gemini_1_15499172424147453_001259_40.png
# train set:  18%|█▊        | 2720/14916 [02:19<11:11, 18.17it/s]
# pupil not detected for image (2716) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016191_gemini_1_15499172424147453_020141_90.png
# train set:  21%|██        | 3167/14916 [02:42<10:35, 18.50it/s]
# pupil not detected for image (3163) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014673_gemini_0_15499172424147453_130105_2.png
# train set:  24%|██▍       | 3603/14916 [03:04<09:02, 20.86it/s]
# pupil not detected for image (3598) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0013672_gemini_1_15499172424147453_164522_70.png
# train set:  29%|██▉       | 4294/14916 [03:40<08:56, 19.81it/s]
# pupil not detected for image (4291) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0018941_gemini_0_15499172424147453_215534_1.png
# train set:  35%|███▌      | 5221/14916 [04:28<07:51, 20.58it/s]
# pupil not detected for image (5216) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014058_gemini_1_15499172424147453_164709_82.png
# train set:  37%|███▋      | 5463/14916 [04:41<08:27, 18.63it/s]
# pupil not detected for image (5459) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0015767_gemini_0_15499172424147453_003222_61.png
# train set:  38%|███▊      | 5652/14916 [04:51<07:06, 21.73it/s]
# pupil not detected for image (5649) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014364_gemini_1_15499172424147453_165341_41.png
# train set:  42%|████▏     | 6250/14916 [05:21<06:57, 20.75it/s]
# pupil not detected for image (6245) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010549_Iritech_E_3_0_4_R_M_N_N_1987_25_2017.bmp
# train set:  43%|████▎     | 6349/14916 [05:27<06:43, 21.21it/s]
# pupil not detected for image (6346) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0009016_Iritech_E_2_3_0_R_M_N_N_1982_34_2017.bmp
# train set:  44%|████▍     | 6604/14916 [05:40<07:14, 19.15it/s]
# pupil not detected for image (6601) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014676_gemini_1_15499172424147453_130105_3.png
# train set:  51%|█████     | 7586/14916 [06:31<06:41, 18.28it/s]
# pupil not detected for image (7582) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0005894_IriTech_E_1_4_0_R_M_N_N_1979_55_2017.bmp
# train set:  55%|█████▌    | 8246/14916 [07:05<05:46, 19.24it/s]
# pupil not detected for image (8243) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016634_gemini_0_15499172424147453_001259_20.png
# train set:  56%|█████▌    | 8309/14916 [07:08<05:29, 20.07it/s]
# pupil not detected for image (8306) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014674_gemini_1_15499172424147453_130105_2.png
# train set:  59%|█████▉    | 8769/14916 [07:32<05:27, 18.75it/s]
# pupil not detected for image (8765) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000497_IriTech_E_0_0_3_L_M_N_N_1981_46_2017.bmp
# train set:  60%|██████    | 8955/14916 [07:42<05:11, 19.14it/s]
# pupil not detected for image (8952) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014634_gemini_1_15499172424147453_125402_82.png
# train set:  61%|██████    | 9061/14916 [07:47<05:07, 19.04it/s]
# pupil not detected for image (9057) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0001858_Iritech_E_0_2_1_L_M_N_N_1976_2_2017.bmp
# train set:  62%|██████▏   | 9301/14916 [07:59<05:04, 18.42it/s]
# pupil not detected for image (9298) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016831_gemini_1_15499172424147453_002855_65.png
# train set:  64%|██████▍   | 9562/14916 [08:13<04:16, 20.85it/s]
# pupil not detected for image (9558) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0002456_Iritech_E_0_2_4_R_M_N_N_1976_67_2017.bmp
# train set:  66%|██████▌   | 9869/14916 [08:28<03:53, 21.64it/s]
# pupil not detected for image (9866) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000023_IriTech_E_0_0_0_L_M_N_N_1981_23_2017.bmp
# train set:  69%|██████▊   | 10224/14916 [08:46<03:47, 20.63it/s]
# pupil not detected for image (10221) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010172_Iritech_E_3_0_2_L_M_N_N_1987_46_2017.bmp
# train set:  69%|██████▊   | 10235/14916 [08:47<03:46, 20.67it/s]
# pupil not detected for image (10232) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014692_gemini_1_15499172424147453_130105_11.png
# train set:  73%|███████▎  | 10883/14916 [09:20<03:09, 21.25it/s]
# pupil not detected for image (10879) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0015766_gemini_1_15499172424147453_003222_59.png
# train set:  76%|███████▋  | 11400/14916 [09:46<02:47, 20.96it/s]
# pupil not detected for image (11396) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014690_gemini_1_15499172424147453_130105_10.png
# train set:  87%|████████▋ | 12941/14916 [11:06<01:48, 18.13it/s]
# pupil not detected for image (12938) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014675_gemini_0_15499172424147453_130105_3.png
# train set:  88%|████████▊ | 13144/14916 [11:17<01:29, 19.84it/s]
# pupil not detected for image (13140) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000561_IriTech_E_0_0_3_R_M_N_N_1981_40_2017.bmp
# train set:  92%|█████████▏| 13755/14916 [11:49<00:57, 20.28it/s]
# pupil not detected for image (13751) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010114_Iritech_E_3_0_1_R_M_N_N_1987_70_2017.bmp
# train set:  93%|█████████▎| 13945/14916 [11:59<00:51, 18.76it/s]
# pupil not detected for image (13942) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014420_gemini_1_15499172424147453_165341_69.png
# train set:  94%|█████████▍| 13996/14916 [12:01<00:48, 18.95it/s]
# pupil not detected for image (13992) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014691_gemini_0_15499172424147453_130105_11.png
# train set:  94%|█████████▍| 14070/14916 [12:05<00:41, 20.24it/s]
# pupil not detected for image (14068) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0003566_IriTech_E_1_1_2_R_M_N_N_1983_81_2017.bmp
# train set:  96%|█████████▌| 14282/14916 [12:17<00:32, 19.49it/s]
# pupil not detected for image (14279) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016681_gemini_1_15499172424147453_001259_46.png
# train set:  98%|█████████▊| 14557/14916 [12:31<00:19, 18.65it/s]
# pupil not detected for image (14554) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000693_IriTech_E_0_0_4_R_M_N_N_1981_20_2017.bmp
# test set:  14%|█▍        | 303/2132 [00:12<01:05, 28.09it/s]
# pupil not detected for image (298) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0008189_Iritech_E_2_2_1_L_M_N_N_1970_23_2017.bmp
# test set:  26%|██▌       | 554/2132 [00:21<00:54, 29.12it/s]
# pupil not detected for image (550) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0015822_gemini_1_15499172424147453_003222_91.png
# test set:  33%|███▎      | 697/2132 [00:26<00:51, 28.03it/s]
# pupil not detected for image (692) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0009017_Iritech_E_2_3_0_R_M_N_N_1982_35_2017.bmp
# test set:  50%|█████     | 1070/2132 [00:39<00:38, 27.65it/s]
# pupil not detected for image (1065) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0013472_gemini_0_15499172424147453_164448_20.png
# test set:  79%|███████▉  | 1690/2132 [01:02<00:16, 26.57it/s]
# pupil not detected for image (1685) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0005878_IriTech_E_1_4_0_R_M_N_N_1979_39_2017.bmp
# test set:  82%|████████▏ | 1748/2132 [01:04<00:13, 28.36it/s]
# pupil not detected for image (1742) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0008311_Iritech_E_2_2_1_R_M_N_N_1970_69_2017.bmp
# test set:  86%|████████▌ | 1823/2132 [01:06<00:10, 28.78it/s]
# pupil not detected for image (1817) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0010492_Iritech_E_3_0_4_L_M_N_N_1987_46_2017.bmp
# test set:  94%|█████████▍| 2006/2132 [01:13<00:04, 28.63it/s]
# pupil not detected for image (2001) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0001059_Iritech_E_0_1_1_L_M_N_N_1982_56_2017.bmp
# test set:  99%|█████████▉| 2113/2132 [01:17<00:00, 28.19it/s]
# pupil not detected for image (2108) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0018942_gemini_1_15499172424147453_215534_1.png
# val set:   1%|          | 52/4261 [00:01<02:26, 28.67it/s]
# pupil not detected for image (47) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0014057_gemini_0_15499172424147453_164709_82.png
# val set:   4%|▍         | 174/4261 [00:06<02:25, 28.07it/s]
# pupil not detected for image (168) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0016190_gemini_0_15499172424147453_020141_90.png
# val set:  17%|█▋        | 724/4261 [00:26<02:12, 26.79it/s]
# pupil not detected for image (719) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0010566_Iritech_E_3_0_4_R_M_N_N_1987_44_2017.bmp
# val set:  23%|██▎       | 964/4261 [00:35<02:04, 26.40it/s]
# pupil not detected for image (959) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0002371_Iritech_E_0_2_4_L_M_N_N_1976_53_2017.bmp
# val set:  70%|██████▉   | 2980/4261 [01:50<00:46, 27.49it/s]
# pupil not detected for image (2975) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0003832_IriTech_E_1_1_4_R_M_N_N_1983_29_2017.bmp
# val set:  82%|████████▏ | 3481/4261 [02:08<00:28, 26.95it/s]
# pupil not detected for image (3476) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0017294_gemini_1_15499172424147453_014820_2.png
# val set:  82%|████████▏ | 3507/4261 [02:09<00:26, 28.60it/s]
# pupil not detected for image (3502) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0014730_gemini_1_15499172424147453_130105_31.png
# val set:  90%|████████▉ | 3816/4261 [02:20<00:15, 29.01it/s]
# pupil not detected for image (3810) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0000587_IriTech_E_0_0_3_R_M_N_N_1981_68_2017.bmp
# val set:  91%|█████████ | 3870/4261 [02:22<00:14, 27.91it/s]
# pupil not detected for image (3864) /home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0002285_Iritech_E_0_2_3_R_M_N_N_1976_45_2017.bmp

# %% [markdown]
# # Evaluation Metrics

# %%
len(files_with_error)
# Out:
# 54

# %%
print(f'Total images: {len(all_iou)}\n')
print(f'Mean Dist error: {np.mean([m["pupil_err"][0] for m in all_iou])}')
print(f'Std Dist error: {np.std([m["pupil_err"][0] for m in all_iou])}')
print(f'Max Dist error: {np.max([m["pupil_err"][0] for m in all_iou])}')
print(f'Min Dist error: {np.min([m["pupil_err"][0] for m in all_iou])}')
print('\n', '-'*40, '\n')
print(f'Mean Radio error: {np.mean([m["pupil_err"][-1] for m in all_iou])}')
print(f'Std Radio error: {np.std([m["pupil_err"][-1] for m in all_iou])}')
print(f'Max Radio error: {np.max([m["pupil_err"][-1] for m in all_iou])}')
print(f'Min Radio error: {np.min([m["pupil_err"][-1] for m in all_iou])}')
print('\n', '-'*40, '\n')
print(f'Mean IoU: {np.mean([m["miou"] for m in all_iou])}')
print(f'Std IoU: {np.std([m["miou"] for m in all_iou])}')
print(f'Min IoU: {np.min([m["miou"] for m in all_iou])}')
print(f'Max IoU: {np.max([m["miou"] for m in all_iou])}')
print(f'Avg time: {np.mean([m["inf_time"] for m in all_iou])}')
print(f'Std time: {np.std([m["inf_time"] for m in all_iou])}')
print('\n', '-'*40, '\n')

for key in all_iou[0]['_classes'].keys():
    print(f'{key} miou: {np.mean([m["_classes"][key] for m in all_iou])}')
# Out:
# Total images: 21255
#
# Mean Dist error: 1.072233502536559
# Std Dist error: 1.7692776901013205
# Max Dist error: 193.07252523339514
# Min Dist error: 0.0
#
#  ----------------------------------------
#
# Mean Radio error: 0.819383674429546
# Std Radio error: 1.1724432169498753
# Max Radio error: 20
# Min Radio error: 0
#
#  ----------------------------------------
#
# Mean IoU: 0.9157514156451898
# Std IoU: 0.040297588590626335
# Min IoU: 0.4569625297756305
# Max IoU: 0.97961197172351
# Avg time: 0.028281063215784732
# Std time: 0.007158000847843957
#
#  ----------------------------------------
#
# eye miou: 0.9885341591921466
# iris miou: 0.8644337285651829
# pupil miou: 0.8942863591782402

# %% [markdown]
# # Check Radio Errors

# %% [markdown]
# ### max radio diff

# %%
id_m = np.argmax([m["pupil_err"][-1] for m in all_iou])
all_iou[id_m]
# Out:
# {'fname': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010479_Iritech_E_3_0_4_L_M_N_N_1987_33_2017.bmp',
#  'set': 'train',
#  'miou': 0.5444616342662901,
#  'coords_pupil': array([151, 149,   1,   4]),
#  'pupil_err': (7.280109889280518, 20),
#  'inf_time': 0.02814459800720215,
#  '_classes': {'eye': 0.9859962746070247,
#   'iris': 0.5833051706657655,
#   'pupil': 0.06408345752608048}}

# %% [markdown]
# ### max distance error

# %%
id_m = np.argmax([m["pupil_err"][0] for m in all_iou])
all_iou[id_m]
# Out:
# {'fname': '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0001468_Iritech_E_0_1_4_L_M_N_N_1982_1_2017.bmp',
#  'set': 'train',
#  'miou': 0.5442684374664856,
#  'coords_pupil': array([6, 6, 6, 6]),
#  'pupil_err': (193.07252523339514, 15),
#  'inf_time': 0.033193349838256836,
#  '_classes': {'eye': 0.985026200754799,
#   'iris': 0.6477791116446578,
#   'pupil': 0.0}}

# %% [markdown]
# # Metrics per time

# %%
struct = {
    # (nombre, r_pupil, miou, pupil_iou, pupil_err)
    '0 min': [],
    '15 min': [],
    '30 min': [],
    '45 min': [],
    '60 min': []
}

for elem in all_iou:
    fname = os.path.basename(elem['fname'])
    if 'gemini' in [a.lower() for a in fname.split('_')]: continue
    folder_time = fname.split('_')[5]
    key = f'{int(folder_time)*15} min'
    struct[key].append([
        elem['fname'],
        elem['coords_pupil'][-1],
        elem['miou'],
        elem['_classes']['pupil'],
        elem['pupil_err'],
    ])

# %%
pupil_radios = {
    '0 min': [],
    '15 min': [],
    '30 min': [],
    '45 min': [],
    '60 min': []
}

pupil_errors = {
    '0 min': [],
    '15 min': [],
    '30 min': [],
    '45 min': [],
    '60 min': []
}

_what = []

for key in struct:
    for elem in struct[key]:
#         if elem[1] <= 120 and elem[1] >= 18: 
#             pupil_radios[key].append(elem[1]) # elem: (nombre, r_pupil, miou, pupil_iou, pupil_err)
#             pupil_errors[key].append(elem[-1])
#         else:
#             _what.append(elem)
		
		# elem: (nombre, r_pupil, miou, pupil_iou, pupil_err)
        pupil_radios[key].append(elem[1])
        pupil_errors[key].append(elem[-1])
    pupil_radios[key] = np.array(pupil_radios[key])
    pupil_errors[key] = np.array(pupil_errors[key])
    
_sum = 0
for key in pupil_radios:
    _sum += pupil_radios[key].shape[0]
print(f'Total radios: {_sum}')
print('check predictions:', len(_what))
# Out:
# Total radios: 13218
# check predictions: 0

# %%
for key in pupil_errors:
    print(f'{key} dist err mean: {np.mean([err[0] for err in pupil_errors[key]])}')
    print(f'{key} dist err median: {np.median([err[0] for err in pupil_errors[key]])}')
    print(f'{key} dist err std: {np.std([err[0] for err in pupil_errors[key]])}')
    print(f'{key} dist err min: {np.min([err[0] for err in pupil_errors[key]])}')
    print(f'{key} dist err max: {np.max([err[0] for err in pupil_errors[key]])}')
    print()
    
    print(f'{key} radio err mean: {np.mean([err[-1] for err in pupil_errors[key]])}')
    print(f'{key} radio err median: {np.median([err[-1] for err in pupil_errors[key]])}')
    print(f'{key} radio err std: {np.std([err[-1] for err in pupil_errors[key]])}')
    print(f'{key} radio err min: {np.min([err[-1] for err in pupil_errors[key]])}')
    print(f'{key} radio err max: {np.max([err[-1] for err in pupil_errors[key]])}')
    print('-'*40)
    print()
# Out:
# 0 min dist err mean: 0.8267112087759715
# 0 min dist err median: 1.0
# 0 min dist err std: 0.9201019951306664
# 0 min dist err min: 0.0
# 0 min dist err max: 8.06225774829855
#
# 0 min radio err mean: 0.6423746889441877
# 0 min radio err median: 1.0
# 0 min radio err std: 0.8661236969801829
# 0 min radio err min: 0.0
# 0 min radio err max: 16.0
# ----------------------------------------
#
# 15 min dist err mean: 0.9577863205992034
# 15 min dist err median: 1.0
# 15 min dist err std: 1.1367493391370014
# 15 min dist err min: 0.0
# 15 min dist err max: 20.615528128088304
#
# 15 min radio err mean: 0.6684100418410042
# 15 min radio err median: 1.0
# 15 min radio err std: 0.9024331648836201
# 15 min radio err min: 0.0
# 15 min radio err max: 16.0
# ----------------------------------------
#
# 30 min dist err mean: 1.303794519790352
# 30 min dist err median: 1.0
# 30 min dist err std: 1.925179011257692
# 30 min dist err min: 0.0
# 30 min dist err max: 26.1725046566048
#
# 30 min radio err mean: 0.7803488786044855
# 30 min radio err median: 1.0
# 30 min radio err std: 1.1071911706629884
# 30 min radio err min: 0.0
# 30 min radio err max: 16.0
# ----------------------------------------
#
# 45 min dist err mean: 0.8444060283855294
# 45 min dist err median: 1.0
# 45 min dist err std: 0.8072489231324755
# 45 min dist err min: 0.0
# 45 min dist err max: 7.0710678118654755
#
# 45 min radio err mean: 0.6874236874236874
# 45 min radio err median: 1.0
# 45 min radio err std: 1.0054676312469257
# 45 min radio err min: 0.0
# 45 min radio err max: 18.0
# ----------------------------------------
#
# 60 min dist err mean: 0.9438219289361579
# 60 min dist err median: 1.0
# 60 min dist err std: 4.130787499062153
# 60 min dist err min: 0.0
# 60 min dist err max: 193.07252523339514
#
# 60 min radio err mean: 0.693967415235579
# 60 min radio err median: 1.0
# 60 min radio err std: 1.0134079890896985
# 60 min radio err min: 0.0
# 60 min radio err max: 20.0
# ----------------------------------------

# %%
for key in pupil_radios:
    print(f'{key} mean: {pupil_radios[key].mean()}')
    print(f'{key} std: {pupil_radios[key].std()}')
    print(f'{key} min: {pupil_radios[key].min()}')
    print(f'{key} max: {pupil_radios[key].max()}')
    print()
# Out:
# 0 min mean: 19.654461429079277
# 0 min std: 4.380179337720714
# 0 min min: 6
# 0 min max: 37
#
# 15 min mean: 19.668061366806135
# 15 min std: 3.7320464892105534
# 15 min min: 1
# 15 min max: 31
#
# 30 min mean: 21.337130651477395
# 30 min std: 5.621240083455413
# 30 min min: 3
# 30 min max: 43
#
# 45 min mean: 20.785917785917785
# 45 min std: 3.6711257576674186
# 45 min min: 6
# 45 min max: 36
#
# 60 min mean: 20.464553060325848
# 60 min std: 4.434408539310266
# 60 min min: 4
# 60 min max: 35

# %% [markdown]
# # Worst Image

# %%
d_names = [elem['fname'] for elem in all_iou]
d_set = [elem['set'] for elem in all_iou]
s_iou = [elem['miou'] for elem in all_iou]

# %%
min_iou = np.where(np.array(s_iou) == np.min(s_iou))[0][0]
fname_min_iou = d_names[min_iou]
set_min_iou = d_set[min_iou]
# d_names = d1.images + d2.images + d3.images
# min_name = next(fname for fname in d_names if fname_min_iou in fname)
# min_name
set_min_iou, fname_min_iou, min_iou
# Out:
# ('train',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016038_gemini_1_15499172424147453_020141_1.png',
#  6447)

# %%
_miou = s_iou.copy()
_miou = np.sort(_miou)
_miou[:10]
# Out:
# array([0.45696253, 0.47960839, 0.49532545, 0.50557608, 0.50581877,
#        0.52091378, 0.53872135, 0.53892157, 0.54426844, 0.54446163])

# %%
d = [gen[0] for gen in generators if gen[1] == set_min_iou][0]
fname = fname_min_iou.split('/')[-1]
im, lb = d.get_image_by_name(fname)

output_image = model.predict(im)[0]
iou = class_mean_iou(output_image, lb[0, ...], d.class_info)
output_image = np.argmax(output_image, axis=-1)

plt.imshow(output_image)
plt.axis('off')
iou
# Out:
# {'eye': 0.8911059612186915,
#  'iris': 0.0007606490872210953,
#  'pupil': 0.479020979020979,
#  'miou': 0.4569625297756305,
#  'stdiou': 0.3638164602249817}

# %%
plt.imshow(im[0, ...])
plt.axis('off')
# Out:
# (-0.5, 319.5, 239.5, -0.5)

# %%
plt.imshow(np.argmax(lb[0, ...], axis=-1))
plt.axis('off')
# Out:
# (-0.5, 319.5, 239.5, -0.5)

# %%
files_with_error
# Out:
# ['/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0013441_gemini_1_15499172424147453_164448_1.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0015765_gemini_0_15499172424147453_003222_59.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016635_gemini_1_15499172424147453_001259_20.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000516_IriTech_E_0_0_3_L_M_N_N_1981_69_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016671_gemini_1_15499172424147453_001259_40.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016191_gemini_1_15499172424147453_020141_90.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014673_gemini_0_15499172424147453_130105_2.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0013672_gemini_1_15499172424147453_164522_70.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0018941_gemini_0_15499172424147453_215534_1.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014058_gemini_1_15499172424147453_164709_82.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0015767_gemini_0_15499172424147453_003222_61.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014364_gemini_1_15499172424147453_165341_41.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010549_Iritech_E_3_0_4_R_M_N_N_1987_25_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0009016_Iritech_E_2_3_0_R_M_N_N_1982_34_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014676_gemini_1_15499172424147453_130105_3.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0005894_IriTech_E_1_4_0_R_M_N_N_1979_55_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016634_gemini_0_15499172424147453_001259_20.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014674_gemini_1_15499172424147453_130105_2.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000497_IriTech_E_0_0_3_L_M_N_N_1981_46_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014634_gemini_1_15499172424147453_125402_82.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0001858_Iritech_E_0_2_1_L_M_N_N_1976_2_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016831_gemini_1_15499172424147453_002855_65.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0002456_Iritech_E_0_2_4_R_M_N_N_1976_67_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000023_IriTech_E_0_0_0_L_M_N_N_1981_23_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010172_Iritech_E_3_0_2_L_M_N_N_1987_46_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014692_gemini_1_15499172424147453_130105_11.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0015766_gemini_1_15499172424147453_003222_59.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014690_gemini_1_15499172424147453_130105_10.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014675_gemini_0_15499172424147453_130105_3.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000561_IriTech_E_0_0_3_R_M_N_N_1981_40_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0010114_Iritech_E_3_0_1_R_M_N_N_1987_70_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014420_gemini_1_15499172424147453_165341_69.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0014691_gemini_0_15499172424147453_130105_11.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0003566_IriTech_E_1_1_2_R_M_N_N_1983_81_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0016681_gemini_1_15499172424147453_001259_46.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/train/0000693_IriTech_E_0_0_4_R_M_N_N_1981_20_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0008189_Iritech_E_2_2_1_L_M_N_N_1970_23_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0015822_gemini_1_15499172424147453_003222_91.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0009017_Iritech_E_2_3_0_R_M_N_N_1982_35_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0013472_gemini_0_15499172424147453_164448_20.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0005878_IriTech_E_1_4_0_R_M_N_N_1979_39_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0008311_Iritech_E_2_2_1_R_M_N_N_1970_69_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0010492_Iritech_E_3_0_4_L_M_N_N_1987_46_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0001059_Iritech_E_0_1_1_L_M_N_N_1982_56_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/test/0018942_gemini_1_15499172424147453_215534_1.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0014057_gemini_0_15499172424147453_164709_82.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0016190_gemini_0_15499172424147453_020141_90.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0010566_Iritech_E_3_0_4_R_M_N_N_1987_44_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0002371_Iritech_E_0_2_4_L_M_N_N_1976_53_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0003832_IriTech_E_1_1_4_R_M_N_N_1983_29_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0017294_gemini_1_15499172424147453_014820_2.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0014730_gemini_1_15499172424147453_130105_31.png',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0000587_IriTech_E_0_0_3_R_M_N_N_1981_68_2017.bmp',
#  '/home/choppy/TOC/datasets/alcohol/alcohol_v7.0/val/0002285_Iritech_E_0_2_3_R_M_N_N_1976_45_2017.bmp']

# %% [markdown]
# # Images with errors

# %%
fig = plt.figure(figsize=(12, 12))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    impath = files_with_error[i-1]
    if 'train' in impath: d = d1
    elif 'test' in impath: d = d2
    else: d = d3
    imname = os.path.basename(impath)
    im, lb = d.get_image_by_name(imname)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(im[0])
plt.show()

# %% [markdown]
# # Ground Truth

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(1, columns*rows +1):
    impath = files_with_error[i-1]
    if 'train' in impath: d = d1
    elif 'test' in impath: d = d2
    else: d = d3
    imname = os.path.basename(impath)
    im, lb = d.get_image_by_name(imname)
    lb = np.argmax(lb[0], axis=-1)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(lb)
plt.show()

# %% [markdown]
# # Prediction

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(1, columns*rows +1):
    impath = files_with_error[i-1]
    if 'train' in impath: d = d1
    elif 'test' in impath: d = d2
    else: d = d3
    imname = os.path.basename(impath)
    im, lb = d.get_image_by_name(imname)
    pred = model.predict(im)[0]
    pred = np.argmax(pred, axis=-1)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(pred)
plt.show()

# %%
fig = plt.figure(figsize=(7, 4))
plt.title('Center dist error')
dst_err = [elem['pupil_err'][0] for elem in all_iou]
sns.distplot(dst_err, bins=int(max(dst_err)))
# sns.distplot(dst_err, bins=10)
plt.xlabel('Euclidean dist (px)')
print('bines:', int(max(dst_err)))
# sns.distplot(dst_err)
# Out:
# bines: 193

# %%
fig, ax = plt.subplots()
data = [elem['pupil_err'][0] for elem in all_iou]
data = np.sort(np.array(data))

if data[-1] > 18:
	data = data[:-3]
	
plt.title(f'Center Dist Error - Total images: {len(data)}')
counts, bins, patches = ax.hist(data, facecolor='blue', edgecolor='gray')

# Set the ticks to be at the edges of the bins.
ax.set_xticks(bins)
ax.set_ylim(0, len(data))
# Set the xaxis's tick labels to be formatted with 1 decimal place...
# ax.xaxis.set_major_formatter(FormatStrFormatter('%0.1f'))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))

# Change the colors of bars at the edges...
# twentyfifth, seventyfifth = np.percentile(data, [5, 95])
# for patch, rightside, leftside in zip(patches, bins[1:], bins[:-1]):
#     if rightside < twentyfifth:
#         patch.set_facecolor('red')
#     elif leftside > seventyfifth:
#         patch.set_facecolor('green')

# Label the raw counts and the percentages below the x-axis...
bin_centers = 1e-4 * np.diff(bins) + bins[:-1]
for count, x in zip(counts, bin_centers):
    # Label the raw counts
    ax.annotate(str(int(count)), xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -20), textcoords='offset points', va='top', ha='center')

    # Label the percentages
    percent = '%0.0f%%' % (100 * float(count) / counts.sum())
    ax.annotate(percent, xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -34), textcoords='offset points', va='top', ha='center')

# %%
fig = plt.figure(figsize=(7, 4))
plt.title('Radio error dist')
rad_err = [elem['pupil_err'][-1] for elem in all_iou]
sns.distplot(rad_err, bins=int(max(rad_err)))
# sns.distplot(dst_err, bins=10)
plt.xlabel('Radii (px)')
print('bines:', int(max(rad_err)))
# Out:
# bines: 20

# %%
fig, ax = plt.subplots()
data = [elem['pupil_err'][-1] for elem in all_iou]
data = np.sort(np.array(data))

if data[-1] > 20:
	data = data[:-3]

plt.title(f'Pupil Error Dist - Total images: {len(data)}')
counts, bins, patches = ax.hist(data, facecolor='green', edgecolor='gray')

# Set the ticks to be at the edges of the bins.
ax.set_xticks(bins)
ax.set_ylim(0, len(data))
# Set the xaxis's tick labels to be formatted with 1 decimal place...
# ax.xaxis.set_major_formatter(FormatStrFormatter('%0.1f'))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))

# Change the colors of bars at the edges...
# twentyfifth, seventyfifth = np.percentile(data, [25, 75])
# for patch, rightside, leftside in zip(patches, bins[1:], bins[:-1]):
#     if rightside < twentyfifth:
#         patch.set_facecolor('red')
#     elif leftside > seventyfifth:
#         patch.set_facecolor('green')

# Label the raw counts and the percentages below the x-axis...
bin_centers = 1e-4 * np.diff(bins) + bins[:-1]
for count, x in zip(counts, bin_centers):
    # Label the raw counts
    ax.annotate(str(int(count)), xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -20), textcoords='offset points', va='top', ha='center')

    # Label the percentages
    percent = '%0.0f%%' % (100 * float(count) / counts.sum())
    ax.annotate(percent, xy=(x, 0), xycoords=('data', 'axes fraction'),
        xytext=(0, -34), textcoords='offset points', va='top', ha='center')
