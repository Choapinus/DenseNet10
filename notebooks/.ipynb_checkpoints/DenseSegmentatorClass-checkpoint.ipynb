# %% [markdown]
# # 1.- Load dependencies

# %%
import os
import sys

# add subpath to notebooks
sys.path.append(os.path.abspath(os.path.join('..')))
# sys.path.append(os.path.abspath(os.path.join('../utils')))
sys.path.append('../')

import cv2
import numpy as np
import matplotlib.pyplot as plt
from imutils.paths import list_images
from dense10_segmentator import DenseSegmentator

import tensorflow as tf

from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import Session
from tensorflow.compat.v1 import ConfigProto

config = ConfigProto()
# dynamically grow GPU memory
config.gpu_options.allow_growth = True
set_session(Session(config=config))

# %load_ext autoreload
# %autoreload 2
# Out:
# 2022-11-04 11:50:32.580316: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-04 11:50:49.439574: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-04 11:50:49.651565: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:50.586942: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:50.587818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:55.882550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:55.884488: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:55.886135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:55.887471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4631 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# # 2.- Set path of weights and config file

# %%
# openeds config
# inifile_path = '../config/openeds_dense10.ini'
# modelpath = '../models/epoch_124_miou_0.9345.h5'

# alcohol config
inifile_path = '../config/segmentator_dense10.ini'
modelpath = '/home/choppy/TOC/densenet10/models/weights/dense_models/blurry_gemini_dense_miou_0.9275.h5'

# %% [markdown]
# # 3.- Instance and load model

# %%
model = DenseSegmentator(modelpath=modelpath, inifile_path=inifile_path)
# Out:
# 2022-11-04 11:50:56.539371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.540947: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.542280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.544132: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.545666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.547041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.548485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.549871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-04 11:50:56.551021: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4631 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# # 4.- Load example images

# %%
# folder_ims = '/home/choppy/TOC/datasets/openeds/ttv/test/images'
# folder_ims = '/media/choppy/WD_BLACK/datasets/OpenEDS/openeds_split/test/images'

folder_ims = "/home/choppy/TOC/datasets/alcohol/alcohol_v7.0"
all_images = sorted([*list_images(folder_ims)])

# %% [markdown]
# # 5.- Select image to segmentate

# %%
image = model.load_image(path=np.random.choice(all_images)) # random image
# image = model.load_image(all_images[0]) # first image

# %% [markdown]
# # 6.- Use "forward" model function to get all image info
# ### Mask and original image shapes will be equal

# %%
info = model.forward(image)
# Out:
# 2022-11-04 11:51:09.518064: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-11-04 11:51:17.358221: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-04 11:51:17.370795: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-04 11:51:17.370876: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-04 11:51:17.371482: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-04 11:51:17.371571: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.

# %% [markdown]
# # 7.- Show image and segmentation map given by the segmentator model

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(121)
plt.imshow(image)
plt.axis('off')

plt.subplot(122)
plt.imshow(np.argmax(info['mask'], axis=-1))
plt.axis('off')

plt.show()

# %% [markdown]
# # 8.- Print data headers given by the model

# %%
list(info.keys())
# Out:
# ['pupil_x',
#  'pupil_y',
#  'pupil_r_min',
#  'pupil_r_max',
#  'iris_x',
#  'iris_y',
#  'iris_r_min',
#  'iris_r_max',
#  'mask',
#  'iris_rubbersheet',
#  'bitwised_iris_rubbersheet',
#  'mask_iris_rubbersheet',
#  'pred_shape',
#  'radii_type_estimator',
#  'original_shape']

# %% [markdown]
# # 9.- Print value of each key

# %%
for k in info:
    if k not in ('mask', 'iris_rubbersheet', 'mask_iris_rubbersheet', 'bitwised_iris_rubbersheet'): # dont print images
        print(f'{k}: \t {info[k]}')
# Out:
# pupil_x: 	 235
# pupil_y: 	 353
# pupil_r_min: 	 45
# pupil_r_max: 	 46
# iris_x: 	 236
# iris_y: 	 350
# iris_r_min: 	 106
# iris_r_max: 	 104
# pred_shape: 	 [320, 320]
# radii_type_estimator: 	 lms3
# original_shape: 	 [480, 640]

# %% [markdown]
# # 10.- Draw circles over predicted regions

# %%
# do inference
str_image = np.random.choice(all_images)
im = model.load_image(str_image)
info = model.forward(im)

# iris
(x, y, r_min, r_max) = (info['iris_x'], info['iris_y'], info['iris_r_min'], info['iris_r_max'])
im = cv2.circle(im, (y, x), r_min, [0, 0, 255], 3)
text = f'Iris center at ({x}, {y}) with radius {r_min}'
cv2.putText(im, text, (10, 450), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2, cv2.LINE_AA)


# pupil
(x, y, r_min, r_max) = (info['pupil_x'], info['pupil_y'], info['pupil_r_min'], info['pupil_r_max'])
im = cv2.circle(im, (y, x), r_min, [0, 255, 10], 2)
text = f'Pupil center at ({x}, {y}) with radius {r_min}'
cv2.putText(im, text, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2, cv2.LINE_AA)


plt.figure(figsize=(10, 8))
plt.imshow(im)

# %% [markdown]
# # Show iris rubbersheet and difference between mode extractions

# %%
h_rs = info['iris_rubbersheet']
plt.imshow(h_rs)

# %%
image = model.load_image(str_image)
plt.imshow(image)

# %%
# change iris_mod_type
# height type is selected as default
old_mode = model.iris_mod_type

model.iris_mod_type = 'width'
info = model.forward(image)
w_rs = info['iris_rubbersheet']
plt.imshow(w_rs)

# return to old mode type
model.iris_mod_type = old_mode

# %%
plt.imshow(h_rs - w_rs)

# %%
diff = h_rs - w_rs
_sum = diff.sum()

if _sum == 0:
    print('No difference over width and height iris extraction method')
else:
    print('There are differences between iris images. They could be moved in X-axis to match')
# Out:
# There are differences between iris images. They could be moved in X-axis to match

# %%
# begin iris binarization with ICA filters

# %%
# show images examples
file1 = '.data/samples/0000784_LG_E_0_0_1_L_M_N_N_1981_9_2017.bmp'
file2 = '.data/samples/0000804_LG_E_0_0_2_L_M_N_N_1981_9_2017.bmp'
file3 = '.data/samples/0001367_Iritech_E_0_1_3_L_M_N_N_1982_56_2017.bmp'

samples = {
    'sample1': model.load_image(file1),
    'sample2': model.load_image(file2),
    'sample3': model.load_image(file3),
}

fig, axes = plt.subplots(1, 3, figsize=(16,3))

for ax, key_s in zip(axes, samples.keys()):
    ax.imshow(samples[key_s])

# %%
# get iris rubbersheet from each image example

samples_info = {}
fig, axes = plt.subplots(3, 3, figsize=(16,3), sharex=True, sharey=True)
axes = axes.T # rotate 3x3 grid example

for key_s, (ax1, ax2, ax3) in zip(samples, axes):
    image = samples[key_s].copy()
    info = model.forward(image)
    
    # get variable to another one more readable
    samples_info[key_s] = info
    
    iris_rs = info.get('iris_rubbersheet')
    mask_iris_rs = info.get('mask_iris_rubbersheet')
    bw_iris = info.get('bitwised_iris_rubbersheet')
    
    ax1.imshow(iris_rs)
    ax1.set_title('Normalized Iris')
    
    ax2.imshow(mask_iris_rs)
    ax2.set_title('Normalized Iris Mask')
    
    ax3.imshow(bw_iris)
    ax3.set_title('Normalized Iris Bitwised')
