# %% [markdown]
# # 1.- Load dependencies

# %%
import os
import sys

# add subpath to notebooks
sys.path.append(os.path.abspath(os.path.join('..')))
# sys.path.append(os.path.abspath(os.path.join('../utils')))
sys.path.append('../')

import cv2
import numpy as np
import matplotlib.pyplot as plt
from imutils.paths import list_images
from dense10_segmentator import DenseSegmentator

import tensorflow as tf

from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import Session
from tensorflow.compat.v1 import ConfigProto

config = ConfigProto()
# dynamically grow GPU memory
config.gpu_options.allow_growth = True
set_session(Session(config=config))

# %load_ext autoreload
# %autoreload 2
# Out:
# 2022-10-19 11:02:58.498968: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2022-10-19 11:02:58.520386: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2599990000 Hz
# 2022-10-19 11:02:58.520952: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55b588d6d5f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-10-19 11:02:58.520966: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-10-19 11:02:58.521663: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-10-19 11:02:58.577909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.578438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design computeCapability: 7.5
# coreClock: 1.335GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-10-19 11:02:58.578688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 11:02:58.580434: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-10-19 11:02:58.581969: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:02:58.582276: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:02:58.584086: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:02:58.585110: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-10-19 11:02:58.588592: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 11:02:58.588706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.589270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.589664: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2022-10-19 11:02:58.589709: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 11:02:58.655235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 11:02:58.655254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2022-10-19 11:02:58.655259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2022-10-19 11:02:58.655409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.655823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.656173: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.656453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5511 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-10-19 11:02:58.657757: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55b58a5fedd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-10-19 11:02:58.657767: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti with Max-Q Design, Compute Capability 7.5

# %% [markdown]
# # 2.- Set path of weights and config file

# %%
# openeds config
inifile_path = '../config/openeds_dense10.ini'
modelpath = '../models/epoch_124_miou_0.9345.h5'

# alcohol config
# inifile_path = '../config/segmentator_dense10.ini'
# modelpath = '/home/choppy/TOC/densenet10/models/weights/dense_models/blurry_gemini_dense_miou_0.9275.h5'

# %% [markdown]
# # 3.- Instance and load model

# %%
model = DenseSegmentator(modelpath=modelpath, inifile_path=inifile_path)
# Out:
# 2022-10-19 11:02:58.823672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.823990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design computeCapability: 7.5
# coreClock: 1.335GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-10-19 11:02:58.824077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 11:02:58.824091: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-10-19 11:02:58.824102: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:02:58.824113: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:02:58.824125: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:02:58.824136: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-10-19 11:02:58.824148: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 11:02:58.824198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.824490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.824745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2022-10-19 11:02:58.824976: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.825242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design computeCapability: 7.5
# coreClock: 1.335GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-10-19 11:02:58.825259: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-19 11:02:58.825272: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-10-19 11:02:58.825283: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:02:58.825294: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:02:58.825305: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:02:58.825316: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-10-19 11:02:58.825328: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 11:02:58.825366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.825652: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.825907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2022-10-19 11:02:58.825923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 11:02:58.825928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2022-10-19 11:02:58.825931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2022-10-19 11:02:58.825989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.826277: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-19 11:02:58.826539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5511 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)

# %% [markdown]
# # 4.- Load example images

# %%
# folder_ims = '/home/choppy/TOC/datasets/openeds/ttv/test/images'
folder_ims = '/media/choppy/WD_BLACK/datasets/OpenEDS/openeds_split/test/images'

# folder_ims = "/home/choppy/TOC/datasets/alcohol/alcohol_v7.0"
all_images = sorted([*list_images(folder_ims)])

# %% [markdown]
# # 5.- Select image to segmentate

# %%
image = model.load_image(path=np.random.choice(all_images)) # random image
# image = model.load_image(all_images[0]) # first image

# %% [markdown]
# # 6.- Use "forward" model function to get all image info
# ### Mask and original image shapes will be equal

# %%
info = model.forward(image)
# Out:
# 2022-10-19 11:03:00.836605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-10-19 11:03:01.556709: W tensorflow/stream_executor/gpu/asm_compiler.cc:81] Running ptxas --version returned 256
# 2022-10-19 11:03:01.590797: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-10-19 11:03:02.429162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# /home/choppy/TOC/densenet10/dense10_segmentator.py:156: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   a, _, _, _ = np.linalg.lstsq(A, B)

# %% [markdown]
# # 7.- Show image and segmentation map given by the segmentator model

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(121)
plt.imshow(image)
plt.axis('off')

plt.subplot(122)
plt.imshow(np.argmax(info['mask'], axis=-1))
plt.axis('off')

plt.show()

# %% [markdown]
# # 8.- Print data headers given by the model

# %%
list(info.keys())
# Out:
# ['pupil_x',
#  'pupil_y',
#  'pupil_r_min',
#  'pupil_r_max',
#  'iris_x',
#  'iris_y',
#  'iris_r_min',
#  'iris_r_max',
#  'mask',
#  'pred_shape',
#  'radii_type_estimator',
#  'original_shape']

# %% [markdown]
# # 9.- Print value of each key

# %%
for k in info:
    if k != 'mask': # dont print mask
        print(f'{k}: \t {info[k]}')
# Out:
# pupil_x: 	 310
# pupil_y: 	 204
# pupil_r_min: 	 22
# pupil_r_max: 	 22
# iris_x: 	 311
# iris_y: 	 211
# iris_r_min: 	 95
# iris_r_max: 	 87
# pred_shape: 	 [240, 320]
# radii_type_estimator: 	 lms3
# original_shape: 	 [640, 400]

# %% [markdown]
# # 10.- Draw circles over predicted regions

# %%
# do inference
im = model.load_image(np.random.choice(all_images))
info = model.forward(im)

# iris
(x, y, r_min, r_max) = (info['iris_x'], info['iris_y'], info['iris_r_min'], info['iris_r_max'])
im = cv2.circle(im, (y, x), r_min, [0, 0, 255], 3)
text = f'Iris center at ({x}, {y}) with radius {r_min}'
cv2.putText(im, text, (10, 450), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2, cv2.LINE_AA)


# pupil
(x, y, r_min, r_max) = (info['pupil_x'], info['pupil_y'], info['pupil_r_min'], info['pupil_r_max'])
im = cv2.circle(im, (y, x), r_min, [0, 255, 10], 2)
text = f'Pupil center at ({x}, {y}) with radius {r_min}'
cv2.putText(im, text, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2, cv2.LINE_AA)


plt.figure(figsize=(10, 8))
plt.imshow(im)
